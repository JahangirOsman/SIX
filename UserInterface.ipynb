# %% [markdown]
# Login page:

# %%
import tkinter as tk
from tkinter import messagebox

def validate_login():
    # Retrieve username and password entered by the user
    entered_username = username.get()
    entered_password = password.get()

    # Replace these with actual validation logic
    # For simplicity, let's assume a hardcoded username and password
    valid_username = "user123"
    valid_password = "password123"

    if entered_username == valid_username and entered_password == valid_password:
        messagebox.showinfo("Login Successful", "Welcome!")
        # Add code to navigate to the next page upon successful login
    else:
        messagebox.showerror("Login Failed", "Invalid username or password")

def show_hide_password():
    if show_password_var.get():
        password.config(show="")
    else:
        password.config(show="*")

def create_account():
    messagebox.showinfo("Create Account", "Redirecting to create account page...")
    # Add code to navigate to the "Create Account" page

# Create main window
root = tk.Tk()
root.title("Login Page")

# Create labels and entries for username and password
username_label = tk.Label(root, text="Username:")
username_label.pack()
username = tk.Entry(root)
username.pack()

password_label = tk.Label(root, text="Password:")
password_label.pack()
password = tk.Entry(root, show="*")
password.pack()

# Create "Show Password" checkbutton
show_password_var = tk.BooleanVar()
show_password_checkbox = tk.Checkbutton(root, text="Show Password", variable=show_password_var, command=show_hide_password)
show_password_checkbox.pack()

# Create login button
login_button = tk.Button(root, text="Login", command=validate_login)
login_button.pack()

# Create "Create Account" button
create_account_button = tk.Button(root, text="Create Account", command=create_account)
create_account_button.pack()

root.mainloop()

# %% [markdown]
# Create account page:

# %%
import tkinter as tk
from tkinter import messagebox

def create_account():
    # Retrieve entered details
    new_username = new_username_entry.get()
    new_password = new_password_entry.get()
    full_name = full_name_entry.get()
    email = email_entry.get()
    phone_number = phone_entry.get()
    
    # Create a larger window to display the entered details
    account_details_window = tk.Toplevel(root)
    account_details_window.title("Account Details")
    account_details_window.geometry("680x300")  # Set the size of the window

    # Display the entered details in the larger window
    details_label = tk.Label(account_details_window, text=
        f"New Username: {new_username}\n"
        f"Full Name: {full_name}\n"
        f"Email: {email}\n"
        f"Phone Number: {phone_number}")
    details_label.pack()

# Create main window
root = tk.Tk()
root.title("Create Account")

# Create labels and entries for user details
new_username_label = tk.Label(root, text="New Username:")
new_username_label.pack()
new_username_entry = tk.Entry(root)
new_username_entry.pack()

new_password_label = tk.Label(root, text="New Password:")
new_password_label.pack()
new_password_entry = tk.Entry(root, show="*")
new_password_entry.pack()

full_name_label = tk.Label(root, text="Full Name:")
full_name_label.pack()
full_name_entry = tk.Entry(root)
full_name_entry.pack()

email_label = tk.Label(root, text="Email:")
email_label.pack()
email_entry = tk.Entry(root)
email_entry.pack()

phone_label = tk.Label(root, text="Phone Number:")
phone_label.pack()
phone_entry = tk.Entry(root)
phone_entry.pack()

# Create "Create Account" button
create_account_button = tk.Button(root, text="Create Account", command=create_account)
create_account_button.pack()

root.mainloop()

# %% [markdown]
# Payment and subscription

# %%
import tkinter as tk
from tkinter import messagebox
from PIL import Image, ImageTk  # PIL library for image handling

def process_payment(subscription):
    selected_payment = payment_var.get()
    
    messagebox.showinfo("Payment Details",
                        f"Selected Subscription: {subscription}\n"
                        f"Selected Payment Method: {selected_payment}")
    # Add code to handle payment processing in your Roku application

# Create main window
root = tk.Tk()
root.title("Subscription and Payment Page")

# Function to resize images while maintaining aspect ratio
def resize_image(img_path, width, height):
    original_image = Image.open(img_path)
    original_image.thumbnail((width, height))
    return ImageTk.PhotoImage(original_image)

# Subscription plans as buttons with logos for different content providers
content_providers = [
    {"name": "Netflix Standard - $13.99/month", "logo": "Netflix.png"},
    {"name": "Hulu (No Ads) - $11.99/month", "logo": "Hulu.png"},
    {"name": "Amazon Prime Video - $12.99/month", "logo": "Prime.png"},
    {"name": "Disney+ - $7.99/month", "logo": "DisneyP.png"},
    {"name": "HBO Max - $14.99/month", "logo": "HBO.jpg"},
    {"name": "Apple TV+ - $4.99/month", "logo": "Atv.jpg"},
    {"name": "Showtime - $10.99/month", "logo": "Showtime.png"},
    {"name": "CBS All Access - $5.99/month", "logo": "CBS.png"}
]

def create_subscription_buttons():
    # Arrange buttons in four columns
    for i, provider in enumerate(content_providers):
        row = i % 4
        col = i // 4
        
        # Load and resize the image for the button
        img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\CP\\{provider['logo']}"
        img = resize_image(img_path, 100, 100)
        
        btn = tk.Button(root, text=provider["name"], image=img, compound=tk.TOP, command=lambda prov=provider["name"]: process_payment(prov))
        btn.image = img  # Retain a reference to the image to prevent garbage collection
        btn.grid(row=row, column=col, padx=10, pady=5)

create_subscription_buttons()

# Payment Methods Radio Buttons
payment_methods = ["Credit Card", "PayPal", "Venmo", "Cash App"]

payment_label = tk.Label(root, text="Select a Payment Method:")
payment_label.grid(row=(len(content_providers) // 4) + 2, column=0, columnspan=4, pady=10)

payment_var = tk.StringVar()
payment_var.set(payment_methods[0])  # Set default payment method

for i, method in enumerate(payment_methods):
    payment_radio = tk.Radiobutton(root, text=method, variable=payment_var, value=method)
    payment_radio.grid(row=(len(content_providers) // 4) + 3 + i, column=0, columnspan=4, padx=5)

root.mainloop()

# %% [markdown]
# Browse/search content menu

# %%
import tkinter as tk
from PIL import Image, ImageTk

def search_content():
    search_query = search_entry.get()
    print(f"Searching for: {search_query}")

def show_movie_info(movie, provider):
    movie_info_label.config(text=f"Selected Movie: {movie}\nContent Provider: {provider}")

# Create main window
root = tk.Tk()
root.title("Browse/Search Content")

# Search bar
search_frame = tk.Frame(root)
search_frame.pack(pady=20)

search_label = tk.Label(search_frame, text="Search:")
search_label.pack(side=tk.LEFT)

search_entry = tk.Entry(search_frame)
search_entry.pack(side=tk.LEFT, padx=10)

search_button = tk.Button(search_frame, text="Search", command=search_content)
search_button.pack(side=tk.LEFT)

# Famous movies list with content providers and posters
movies_list = [
    {"name": "Inception", "provider": "Netflix", "poster": "Inception.jpg"},
    {"name": "The Dark Knight", "provider": "Hulu", "poster": "DarkKnight.jpg"},
    {"name": "The Shawshank Redemption", "provider": "Amazon Prime Video", "poster": "ShawShank.jpg"},
    {"name": "Pulp Fiction", "provider": "Disney+", "poster": "Pulpfiction.jpg"},
    {"name": "The Godfather", "provider": "HBO Max", "poster": "Thegodfather.jpg"},
    {"name": "Fight Club", "provider": "Apple TV+", "poster": "Fightclub.jpg"},
    {"name": "Forrest Gump", "provider": "Showtime", "poster": "Forestgump.jpg"},
    {"name": "Interstellar", "provider": "CBS All Access", "poster": "interstellar.jpg"}
]

movies_frame = tk.Frame(root)
movies_frame.pack(pady=20)

movie_info_label = tk.Label(root, text="")
movie_info_label.pack()

def resize_image(img_path, width, height):
    original_image = Image.open(img_path)
    original_image.thumbnail((width, height))
    return ImageTk.PhotoImage(original_image)

for movie in movies_list:
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\{movie['poster']}"
    img = resize_image(img_path, 100, 150)
    
    movie_btn = tk.Button(movies_frame, text=movie["name"], image=img, compound=tk.TOP,
                          command=lambda m=movie["name"], p=movie["provider"]: show_movie_info(m, p))
    movie_btn.image = img  # Retain a reference to the image to prevent garbage collection
    movie_btn.pack(side=tk.LEFT, padx=10, pady=5)

root.mainloop()

# %% [markdown]
# view playlist page

# %%
import tkinter as tk
from PIL import Image, ImageTk

def show_playlist_info(playlist_name, movies):
    playlist_info_label.config(text=f"Playlist: {playlist_name}\nMovies: {', '.join(movies)}")

# Create main window
root = tk.Tk()
root.title("View Playlist")

# Create dummy playlists with movies
playlists = [
    {"name": "My Playlist 1", "movies": ["Inception", "The Dark Knight", "The Shawshank Redemption"]},
    {"name": "My Playlist 2", "movies": ["Pulp Fiction", "The Godfather", "Fight Club"]},
    {"name": "My Playlist 3", "movies": ["Forrest Gump", "Interstellar"]}
]

# Function to resize images while maintaining aspect ratio
def resize_image(img_path, width, height):
    original_image = Image.open(img_path)
    original_image.thumbnail((width, height))
    return ImageTk.PhotoImage(original_image)

# Display playlists and their movies with posters
playlists_frame = tk.Frame(root)
playlists_frame.pack(pady=20)

playlist_info_label = tk.Label(root, text="")
playlist_info_label.pack()

for playlist in playlists:
    playlist_name = playlist["name"]
    playlist_movies = playlist["movies"]
    
    playlist_label = tk.Label(playlists_frame, text=playlist_name)
    playlist_label.pack()

    movie_posters_frame = tk.Frame(playlists_frame)
    movie_posters_frame.pack()
    
    for movie in playlist_movies:
        for mov in movies_list:
            if mov["name"] == movie:
                img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\{mov['poster']}"
                img = resize_image(img_path, 50, 75)
                poster_label = tk.Label(movie_posters_frame, image=img)
                poster_label.image = img  # Retain a reference to the image to prevent garbage collection
                poster_label.pack(side=tk.LEFT, padx=5)

    playlist_btn = tk.Button(playlists_frame, text="View Playlist", command=lambda p=playlist_name, m=playlist_movies: show_playlist_info(p, m))
    playlist_btn.pack(pady=5)

# Buttons to manage playlist and create new playlist
manage_playlist_frame = tk.Frame(root)
manage_playlist_frame.pack(pady=20)

add_movie_btn = tk.Button(manage_playlist_frame, text="Add Movie to Playlist")
add_movie_btn.pack(side=tk.LEFT, padx=10)

delete_playlist_btn = tk.Button(manage_playlist_frame, text="Delete Playlist")
delete_playlist_btn.pack(side=tk.LEFT, padx=10)

create_playlist_btn = tk.Button(root, text="Create New Playlist")
create_playlist_btn.pack(pady=20)

root.mainloop()

# %% [markdown]
# view/play media page

# %%
import tkinter as tk
from PIL import Image, ImageTk

def play_media(movie):
    selected_movie_label.config(text=f"Selected Movie: {movie}")
    # Add code to handle playing the selected movie media
    # For demonstration purposes, let's display a placeholder image
    media_image_path = "C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\media.png"
    media_image = Image.open(media_image_path)
    media_image = media_image.resize((900, 500))  # Resize image if needed
    media_image_tk = ImageTk.PhotoImage(media_image)
    media_player_label.config(image=media_image_tk)
    media_player_label.image = media_image_tk  # Retain reference to image to prevent garbage collection

# Create main window
root = tk.Tk()
root.title("View/Play Media")

# Dummy list of movies
movies_list = [
    {"name": "Inception", "poster": "Inception.jpg"},
    {"name": "The Dark Knight", "poster": "DarkKnight.jpg"},
    {"name": "The Shawshank Redemption", "poster": "ShawShank.jpg"},
    {"name": "Pulp Fiction", "poster": "Pulpfiction.jpg"},
    {"name": "The Godfather", "poster": "Thegodfather.jpg"},
    {"name": "Fight Club", "poster": "Fightclub.jpg"},
    {"name": "Forrest Gump", "poster": "Forestgump.jpg"},
    {"name": "Interstellar", "poster": "interstellar.jpg"}
]

# Function to resize images while maintaining aspect ratio
def resize_image(img_path, width, height):
    original_image = Image.open(img_path)
    original_image.thumbnail((width, height))
    return ImageTk.PhotoImage(original_image)

# Display movies with posters
movies_frame = tk.Frame(root)
movies_frame.pack(pady=20)

selected_movie_label = tk.Label(root, text="")
selected_movie_label.pack()

for movie in movies_list:
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\{movie['poster']}"
    img = resize_image(img_path, 100, 150)
    
    movie_btn = tk.Button(movies_frame, image=img, command=lambda m=movie["name"]: play_media(m))
    movie_btn.image = img  # Retain a reference to the image to prevent garbage collection
    movie_btn.pack(side=tk.LEFT, padx=10, pady=5)

# Placeholder for media player
media_player_label = tk.Label(root)
media_player_label.pack(pady=20)

root.mainloop()

# %% [markdown]
# Creat new playlist page

# %%
import tkinter as tk
from PIL import Image, ImageTk

def create_playlist():
    selected_provider = content_provider_var.get()
    selected_movies = [movie.get() for movie in selected_movies_list if movie_checked[movie].get()]
    playlist_name = playlist_name_entry.get()

    # For demonstration purposes, print the selected options
    print(f"Playlist Name: {playlist_name}")
    print(f"Selected Content Provider: {selected_provider}")
    print("Selected Movies:")
    for movie in selected_movies:
        print(f"- {movie}")

# Create main window
root = tk.Tk()
root.title("Create New Playlist")

# Dummy list of content providers and movies
content_providers = ["Netflix", "Hulu", "Amazon Prime Video", "Disney+", "HBO Max", "Apple TV+", "Showtime", "CBS All Access"]
movies_list = [
    {"name": "Inception", "poster": "Inception.jpg"},
    {"name": "The Dark Knight", "poster": "DarkKnight.jpg"},
    {"name": "The Shawshank Redemption", "poster": "ShawShank.jpg"},
    {"name": "Pulp Fiction", "poster": "Pulpfiction.jpg"},
    {"name": "The Godfather", "poster": "Thegodfather.jpg"},
    {"name": "Fight Club", "poster": "Fightclub.jpg"},
    {"name": "Forrest Gump", "poster": "Forestgump.jpg"},
    {"name": "Interstellar", "poster": "interstellar.jpg"}
]

# Function to resize images while maintaining aspect ratio
def resize_image(img_path, width, height):
    original_image = Image.open(img_path)
    original_image.thumbnail((width, height))
    return ImageTk.PhotoImage(original_image)

# Create content provider selection
content_provider_var = tk.StringVar()
content_provider_var.set(content_providers[0])  # Set default content provider

content_provider_frame = tk.Frame(root)
content_provider_frame.pack(pady=10)

content_provider_label = tk.Label(content_provider_frame, text="Select Content Provider:")
content_provider_label.pack(side=tk.LEFT)

content_provider_optionmenu = tk.OptionMenu(content_provider_frame, content_provider_var, *content_providers)
content_provider_optionmenu.pack(side=tk.LEFT, padx=10)

# Display movies with posters for selection
movies_frame = tk.Frame(root)
movies_frame.pack(pady=20)

selected_movies_list = []
movie_checked = {}

for movie in movies_list:
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\{movie['poster']}"
    img = resize_image(img_path, 100, 150)
    
    movie_check_var = tk.BooleanVar()
    movie_check_var.set(False)
    movie_checked[movie["name"]] = movie_check_var

    movie_check = tk.Checkbutton(movies_frame, image=img, variable=movie_check_var, onvalue=True, offvalue=False)
    movie_check.image = img  # Retain a reference to the image to prevent garbage collection
    movie_check.pack(side=tk.LEFT, padx=10, pady=5)

    selected_movies_list.append(movie["name"])

# Playlist name entry and create button
playlist_frame = tk.Frame(root)
playlist_frame.pack(pady=10)

playlist_name_label = tk.Label(playlist_frame, text="Enter Playlist Name:")
playlist_name_label.pack(side=tk.LEFT)

playlist_name_entry = tk.Entry(playlist_frame)
playlist_name_entry.pack(side=tk.LEFT, padx=10)

create_playlist_btn = tk.Button(root, text="Create Playlist", command=create_playlist)
create_playlist_btn.pack(pady=20)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk

def create_playlist():
    selected_provider = content_provider_var.get()
    selected_movies = [movie.get() for movie in selected_movies_list if movie_checked[movie].get()]
    playlist_name = playlist_name_entry.get()

    # For demonstration purposes, print the selected options
    print(f"Playlist Name: {playlist_name}")
    print(f"Selected Content Provider: {selected_provider}")
    print("Selected Movies:")
    for movie in selected_movies:
        print(f"- {movie}")

# Create main window
root = tk.Tk()
root.title("Create New Playlist")

# Dummy list of content providers and movies
content_providers = ["Netflix", "Hulu", "Amazon Prime Video", "Disney+", "HBO Max", "Apple TV+", "Showtime", "CBS All Access"]
provider_logos = {
    "Netflix": "Netflix.png",
    "Hulu": "Hulu.png",
    "Amazon Prime Video": "Prime.png",
    "Disney+": "DisneyP.png",
    "HBO Max": "HBO.jpg",
    "Apple TV+": "Atv.jpg",
    "Showtime": "Showtime.png",
    "CBS All Access": "CBS.png"
}
movies_list = [
    {"name": "Inception", "poster": "Inception.jpg"},
    {"name": "The Dark Knight", "poster": "DarkKnight.jpg"},
    {"name": "The Shawshank Redemption", "poster": "ShawShank.jpg"},
    {"name": "Pulp Fiction", "poster": "Pulpfiction.jpg"},
    {"name": "The Godfather", "poster": "Thegodfather.jpg"},
    {"name": "Fight Club", "poster": "Fightclub.jpg"},
    {"name": "Forrest Gump", "poster": "Forestgump.jpg"},
    {"name": "Interstellar", "poster": "interstellar.jpg"}
]

# Function to resize images while maintaining aspect ratio
def resize_image(img_path, width, height):
    original_image = Image.open(img_path)
    original_image.thumbnail((width, height))
    return ImageTk.PhotoImage(original_image)

# Create content provider selection
content_provider_var = tk.StringVar()
content_provider_var.set(content_providers[0])  # Set default content provider

content_provider_frame = tk.Frame(root)
content_provider_frame.pack(pady=10)

content_provider_label = tk.Label(content_provider_frame, text="Select Content Provider:")
content_provider_label.pack(side=tk.LEFT)

content_provider_optionmenu = tk.OptionMenu(content_provider_frame, content_provider_var, *content_providers)
content_provider_optionmenu.pack(side=tk.LEFT, padx=10)

# Display content provider logo
selected_provider_logo = tk.Label(root)
selected_provider_logo.pack(pady=10)

# Keep references to PhotoImage objects
provider_logos_images = {}

def show_provider_logo(*args):
    selected_provider = content_provider_var.get()
    logo_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\CP\\{provider_logos[selected_provider]}"
    img = resize_image(logo_path, 100, 50)
    provider_logo = ImageTk.PhotoImage(img)
    provider_logos_images[selected_provider] = provider_logo  # Store the PhotoImage object
    selected_provider_logo.config(image=provider_logo)

# Display movies with posters for selection
movies_frame = tk.Frame(root)
movies_frame.pack(pady=20)

selected_movies_list = []
movie_checked = {}

for movie in movies_list:
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\{movie['poster']}"
    img = resize_image(img_path, 100, 150)
    
    movie_check_var = tk.BooleanVar()
    movie_check_var.set(False)
    movie_checked[movie["name"]] = movie_check_var

    movie_check = tk.Checkbutton(movies_frame, image=img, variable=movie_check_var, onvalue=True, offvalue=False)
    movie_check.image = img  # Retain a reference to the image to prevent garbage collection
    movie_check.pack(side=tk.LEFT, padx=10, pady=5)

    selected_movies_list.append(movie["name"])

# Playlist name entry and create button
playlist_frame = tk.Frame(root)
playlist_frame.pack(pady=10)

playlist_name_label = tk.Label(playlist_frame, text="Enter Playlist Name:")
playlist_name_label.pack(side=tk.LEFT)

playlist_name_entry = tk.Entry(playlist_frame)
playlist_name_entry.pack(side=tk.LEFT, padx=10)

create_playlist_btn = tk.Button(root, text="Create Playlist", command=create_playlist)
create_playlist_btn.pack(pady=20)

root.mainloop()

# %% [markdown]
# change and manage subscription plans

# %%
import tkinter as tk
from PIL import Image, ImageTk

def cancel_subscription(provider):
    selected_provider_label.config(text=f"Selected Provider: {provider}")
    print(f"Cancelling subscription for: {provider}")

def manage_subscription(provider):
    selected_provider_label.config(text=f"Selected Provider: {provider}")
    print(f"Managing subscription for: {provider}")

def buy_subscription(provider):
    selected_provider_label.config(text=f"Selected Provider: {provider}")
    print(f"Buying subscription for: {provider}")

# Create main window
root = tk.Tk()
root.title("Change and Manage Subscription Plans")

# Dummy list of content providers and their subscription plans
content_providers = [
    {"name": "Netflix Standard - $13.99/month", "logo": "Netflix.png"},
    {"name": "Hulu (No Ads) - $11.99/month", "logo": "Hulu.png"},
    {"name": "Amazon Prime Video - $12.99/month", "logo": "Prime.png"},
    {"name": "Disney+ - $7.99/month", "logo": "DisneyP.png"},
    {"name": "HBO Max - $14.99/month", "logo": "HBO.jpg"},
    {"name": "Apple TV+ - $4.99/month", "logo": "Atv.jpg"},
    {"name": "Showtime - $10.99/month", "logo": "Showtime.png"},
    {"name": "CBS All Access - $5.99/month", "logo": "CBS.png"}
]

# Function to resize images while maintaining aspect ratio
def resize_image(img_path, width, height):
    original_image = Image.open(img_path)
    original_image.thumbnail((width, height))
    return ImageTk.PhotoImage(original_image)

# Display content provider logos and subscription plans in 2 columns with 4 rows
providers_frame = tk.Frame(root)
providers_frame.pack(pady=20)

selected_provider_label = tk.Label(root, text="")
selected_provider_label.pack()

row = 0
col = 0
for provider in content_providers:
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\CP\\{provider['logo']}"
    img = resize_image(img_path, 100, 50)

    provider_frame = tk.Frame(providers_frame)
    provider_frame.grid(row=row, column=col, padx=10, pady=5)

    provider_btn = tk.Button(provider_frame, image=img, text=provider["name"], compound=tk.TOP,
                             command=lambda p=provider["name"]: manage_subscription(p))
    provider_btn.image = img  # Retain a reference to the image to prevent garbage collection
    provider_btn.pack()

    cancel_btn = tk.Button(provider_frame, text="Cancel", command=lambda p=provider["name"]: cancel_subscription(p))
    cancel_btn.pack(side=tk.LEFT, padx=5)

    buy_btn = tk.Button(provider_frame, text="Renew or Buy", command=lambda p=provider["name"]: buy_subscription(p))
    buy_btn.pack(side=tk.LEFT, padx=5)

    col += 1
    if col == 2:  # Change to 4 for 4 columns
        col = 0
        row += 1

root.mainloop()

# %% [markdown]
# logout page

# %%
import tkinter as tk
from PIL import Image, ImageTk

def switch_profile():
    # Add code to switch profiles
    print("Switching profiles...")

def turn_off_roku():
    # Add code to turn off Roku
    print("Turning off Roku...")

# Create main window
root = tk.Tk()
root.title("Logout and Settings Page")

# Load and display the background image without antialiasing
bg_image_path = "C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\Roku_lo.webp"
bg_image = Image.open(bg_image_path)
bg_photo = ImageTk.PhotoImage(bg_image)

bg_label = tk.Label(root, image=bg_photo)
bg_label.image = bg_photo  # Retain a reference to the image to prevent garbage collection
bg_label.place(x=0, y=0, relwidth=1, relheight=1)

# Buttons for logout, switch profiles, and turn off Roku
logout_btn = tk.Button(root, text="Logout", command=root.destroy)
logout_btn.place(x=20, y=20)

switch_profile_btn = tk.Button(root, text="Switch Profiles", command=switch_profile)
switch_profile_btn.place(x=20, y=50)

turn_off_roku_btn = tk.Button(root, text="Turn Off Roku", command=turn_off_roku)
turn_off_roku_btn.place(x=20, y=80)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk

def switch_profile():
    # Add code to switch profiles
    print("Switching profiles...")

def turn_off_roku():
    # Add code to turn off Roku
    print("Turning off Roku...")

# Create main window
root = tk.Tk()
root.title("Logout and Settings Page")

# Load and resize the background image
bg_image_path = "C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\Roku_lo.webp"
bg_image = Image.open(bg_image_path)
bg_image = bg_image.resize((900, 900))  # Resize the image to 900x900
bg_photo = ImageTk.PhotoImage(bg_image)

bg_label = tk.Label(root, image=bg_photo)
bg_label.image = bg_photo  # Retain a reference to the image to prevent garbage collection
bg_label.place(x=0, y=0, relwidth=1, relheight=1)

# Get the resized window dimensions
window_width = 900
window_height = 900

# Set the window size
root.geometry(f"{window_width}x{window_height}")

# Calculate button positions in the center
button_x = (window_width - 100) // 2  # Assuming button width as 100
button_y1 = 200  # Adjust the vertical position of buttons as needed
button_y2 = 230
button_y3 = 260

# Buttons for logout, switch profiles, and turn off Roku
logout_btn = tk.Button(root, text="Logout", command=root.destroy)
logout_btn.place(x=button_x, y=button_y1)

switch_profile_btn = tk.Button(root, text="Switch Profiles", command=switch_profile)
switch_profile_btn.place(x=button_x, y=button_y2)

turn_off_roku_btn = tk.Button(root, text="Turn Off Roku", command=turn_off_roku)
turn_off_roku_btn.place(x=button_x, y=button_y3)

root.mainloop()
# Out:
# Switching profiles...

# %% [markdown]
# Main menu

# %%
import tkinter as tk
from PIL import Image, ImageTk

def display_settings():
    # Add code to display settings
    print("Displaying settings...")

# Create main window
root = tk.Tk()
root.title("Roku Main Menu")

# Load and display the background image
bg_image_path = "C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\Roku_lo.webp"
bg_image = Image.open(bg_image_path)
bg_photo = ImageTk.PhotoImage(bg_image)

bg_label = tk.Label(root, image=bg_photo)
bg_label.image = bg_photo  # Retain a reference to the image to prevent garbage collection
bg_label.place(x=0, y=0, relwidth=1, relheight=1)

# Settings button at top right
settings_btn = tk.Button(root, text="Settings", command=display_settings, bg="#6E2594", fg="white")
settings_btn.place(x=800, y=20)

# Content provider logos
content_providers = [
    {"name": "Netflix", "logo": "Netflix.png"},
    {"name": "Hulu ", "logo": "Hulu.png"},
    {"name": "Amazon Prime Video ", "logo": "Prime.png"},
    {"name": "Disney+ ", "logo": "DisneyP.png"},
    {"name": "HBO Max ", "logo": "HBO.jpg"},
    {"name": "Apple TV+ ", "logo": "Atv.jpg"},
    {"name": "Showtime ", "logo": "Showtime.png"},
    {"name": "CBS All Access ", "logo": "CBS.png"}
]

# Display content provider logos on the right side
provider_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
provider_frame.place(x=650, y=50)

for idx, provider in enumerate(content_providers):
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\CP\\{provider['logo']}"
    img = Image.open(img_path)
    img = img.resize((100, 50))  # Resize images
    provider_logo = ImageTk.PhotoImage(img)

    provider_btn = tk.Button(provider_frame, image=provider_logo, text=provider["name"],
                             compound=tk.TOP, bg="#6E2594", fg="white", bd=0)
    provider_btn.image = provider_logo  # Retain a reference to the image to prevent garbage collection
    provider_btn.grid(row=idx, column=0, padx=10, pady=5)

# Options on the right side
options_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
options_frame.place(x=50, y=200)

options = [
    "Login", "Subscription & Payment", "Browse/Search Content", "View Playlist",
    "View/Play Media", "Create New Playlist", "Change & Manage Subscriptions", "Logout"
]

for idx, option in enumerate(options):
    option_btn = tk.Button(options_frame, text=option, bg="#6E2594", fg="white", bd=0, width=20)
    option_btn.grid(row=idx, column=0, padx=10, pady=5)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk

def display_settings():
    # Add code to display settings
    print("Displaying settings...")

# Create main window
root = tk.Tk()
root.title("Roku Main Menu")

# Load and display the background image
bg_image_path = "C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\Roku_lo.webp"
bg_image = Image.open(bg_image_path)
bg_photo = ImageTk.PhotoImage(bg_image.resize((1280, 720)))  # Resize background image
bg_label = tk.Label(root, image=bg_photo)
bg_label.place(x=0, y=0, relwidth=1, relheight=1)

# Content provider logos on the left side
content_providers = [
    {"name": "Netflix Standard ", "logo": "Netflix.png"},
    {"name": "Hulu", "logo": "Hulu.png"},
    {"name": "Amazon Prime Video", "logo": "Prime.png"},
    {"name": "Disney+ ", "logo": "DisneyP.png"},
    {"name": "HBO Max ", "logo": "HBO.jpg"},
    {"name": "Apple TV+ ", "logo": "Atv.jpg"},
    {"name": "Showtime ", "logo": "Showtime.png"},
    {"name": "CBS All Access ", "logo": "CBS.png"}
]

provider_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
provider_frame.place(x=50, y=50)

for idx, provider in enumerate(content_providers):
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\CP\\{provider['logo']}"
    img = Image.open(img_path)
    img = img.resize((100, 70))  # Resize images
    provider_logo = ImageTk.PhotoImage(img)

    provider_btn = tk.Button(provider_frame, image=provider_logo, text=provider["name"],
                             compound=tk.TOP, bg="#6E2594", fg="white", bd=0)
    provider_btn.image = provider_logo  # Retain a reference to the image to prevent garbage collection
    provider_btn.grid(row=idx // 2, column=idx % 2, padx=10, pady=5)

# Heading for frequently watched movies
heading_label = tk.Label(root, text="Frequently Watched Movies", bg="#6E2594", fg="white", font=("Arial", 12))
heading_label.place(x=50, y=300)

# Frequently watched movies on the left side
movies_list = [
    {"name": "Inception", "poster": "Inception.jpg"},
    {"name": "The Dark Knight", "poster": "DarkKnight.jpg"},
    {"name": "The Shawshank Redemption", "poster": "ShawShank.jpg"},
    {"name": "Pulp Fiction", "poster": "Pulpfiction.jpg"},
    {"name": "The Godfather", "poster": "Thegodfather.jpg"},
    {"name": "Fight Club", "poster": "Fightclub.jpg"},
    {"name": "Forrest Gump", "poster": "Forestgump.jpg"},
    {"name": "Interstellar", "poster": "interstellar.jpg"}
]

movies_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
movies_frame.place(x=50, y=350)

for idx, movie in enumerate(movies_list):
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\{movie['poster']}"
    img = Image.open(img_path)
    img = img.resize((100, 80))  # Resize posters
    movie_poster = ImageTk.PhotoImage(img)

    poster_label = tk.Label(movies_frame, image=movie_poster, text=movie["name"],
                            compound=tk.TOP, bg="#6E2594", fg="white", bd=0)
    poster_label.image = movie_poster  # Retain a reference to the image to prevent garbage collection
    poster_label.grid(row=idx // 2, column=idx % 2, padx=10, pady=5)

# Options on the right side
options_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
options_frame.place(x=650, y=50)

options = [
    "Login", "Subscription & Payment", "Browse/Search Content", "View Playlist",
    "View/Play Media", "Create New Playlist", "Change & Manage Subscriptions", "Logout"
]

for idx, option in enumerate(options):
    option_btn = tk.Button(options_frame, text=option, bg="#6E2594", fg="white", bd=0, width=20)
    option_btn.grid(row=idx, column=0, padx=10, pady=5)

# Settings button at top right
settings_btn = tk.Button(root, text="Settings", command=display_settings, bg="#6E2594", fg="white")
settings_btn.place(x=850, y=50)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk

def display_settings():
    # Add code to display settings
    print("Displaying settings...")

# Create main window
root = tk.Tk()
root.title("Roku Main Menu")

# Load and display the background image
bg_image_path = "C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\Roku_lo.webp"
bg_image = Image.open(bg_image_path)
bg_photo = ImageTk.PhotoImage(bg_image.resize((1280, 720)))  # Resize background image
bg_label = tk.Label(root, image=bg_photo)
bg_label.place(x=0, y=0, relwidth=1, relheight=1)

# Content provider logos on the left side with a heading
content_providers = [
    {"name": "Netflix Standard ", "logo": "Netflix.png"},
    {"name": "Hulu", "logo": "Hulu.png"},
    {"name": "Amazon Prime Video", "logo": "Prime.png"},
    {"name": "Disney+ ", "logo": "DisneyP.png"},
    {"name": "HBO Max ", "logo": "HBO.jpg"},
    {"name": "Apple TV+ ", "logo": "Atv.jpg"},
    {"name": "Showtime ", "logo": "Showtime.png"},
    {"name": "CBS All Access ", "logo": "CBS.png"}
]

provider_heading_label = tk.Label(root, text="Content Providers", bg="#6E2594", fg="white", font=("Arial", 12))
provider_heading_label.place(x=50, y=50)

provider_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
provider_frame.place(x=50, y=80)

for idx, provider in enumerate(content_providers):
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\CP\\{provider['logo']}"
    img = Image.open(img_path)
    img = img.resize((100, 70))  # Resize images
    provider_logo = ImageTk.PhotoImage(img)

    provider_btn = tk.Button(provider_frame, image=provider_logo, text=provider["name"],
                             compound=tk.TOP, bg="#6E2594", fg="white", bd=0)
    provider_btn.image = provider_logo  # Retain a reference to the image to prevent garbage collection
    provider_btn.grid(row=idx // 4, column=idx % 4, padx=10, pady=5)

# Heading for frequently watched movies
movies_heading_label = tk.Label(root, text="Frequently Watched Movies", bg="#6E2594", fg="white", font=("Arial", 12))
movies_heading_label.place(x=50, y=300)

# Frequently watched movies on the left side in a 2 rows x 4 columns grid
movies_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
movies_frame.place(x=50, y=330)

movies_list = [
    {"name": "Inception", "poster": "Inception.jpg"},
    {"name": "The Dark Knight", "poster": "DarkKnight.jpg"},
    {"name": "The Shawshank Redemption", "poster": "ShawShank.jpg"},
    {"name": "Pulp Fiction", "poster": "Pulpfiction.jpg"},
    {"name": "The Godfather", "poster": "Thegodfather.jpg"},
    {"name": "Fight Club", "poster": "Fightclub.jpg"},
    {"name": "Forrest Gump", "poster": "Forestgump.jpg"},
    {"name": "Interstellar", "poster": "interstellar.jpg"}
]

for idx, movie in enumerate(movies_list):
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\{movie['poster']}"
    img = Image.open(img_path)
    img = img.resize((100, 150))  # Resize posters
    movie_poster = ImageTk.PhotoImage(img)

    poster_label = tk.Label(movies_frame, image=movie_poster, text=movie["name"],
                            compound=tk.TOP, bg="#6E2594", fg="white", bd=0)
    poster_label.image = movie_poster  # Retain a reference to the image to prevent garbage collection
    poster_label.grid(row=idx // 4, column=idx % 4, padx=10, pady=5)

# Options on the right side
options_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
options_frame.place(x=950, y=50)

options = [
    "Login", "Subscription & Payment", "Browse/Search Content", "View Playlist",
    "View/Play Media", "Create New Playlist", "Change & Manage Subscriptions", "Logout"
]

for idx, option in enumerate(options):
    option_btn = tk.Button(options_frame, text=option, bg="#6E2594", fg="white", bd=0, width=30)
    option_btn.grid(row=idx, column=0, padx=10, pady=5)

# Settings button at top right
settings_btn = tk.Button(root, text="Settings", command=display_settings, bg="#6E2594", fg="white")
settings_btn.place(x=1150, y=50)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk

def display_settings():
    # Add code to display settings
    print("Displaying settings...")

# Create main window
root = tk.Tk()
root.title("Roku Main Menu")

# Load and display the background image
bg_image_path = "C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\Roku_lo.webp"
bg_image = Image.open(bg_image_path)
bg_photo = ImageTk.PhotoImage(bg_image.resize((1280, 720)))  # Resize background image
bg_label = tk.Label(root, image=bg_photo)
bg_label.place(x=0, y=0, relwidth=1, relheight=1)

# Content provider logos on the left side with a heading
content_providers = [
    {"name": "Netflix Standard ", "logo": "Netflix.png"},
    {"name": "Hulu", "logo": "Hulu.png"},
    {"name": "Amazon Prime Video", "logo": "Prime.png"},
    {"name": "Disney+ ", "logo": "DisneyP.png"},
    {"name": "HBO Max ", "logo": "HBO.jpg"},
    {"name": "Apple TV+ ", "logo": "Atv.jpg"},
    {"name": "Showtime ", "logo": "Showtime.png"},
    {"name": "CBS All Access ", "logo": "CBS.png"}
]

provider_heading_label = tk.Label(root, text="Content Providers", bg="#6E2594", fg="white", font=("Arial", 12))
provider_heading_label.place(x=50, y=50)

provider_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
provider_frame.place(x=50, y=80, relwidth=0.375, relheight=0.75)

for idx, provider in enumerate(content_providers):
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\CP\\{provider['logo']}"
    img = Image.open(img_path)
    img = img.resize((100, 70))  # Resize images
    provider_logo = ImageTk.PhotoImage(img)

    provider_btn = tk.Button(provider_frame, image=provider_logo, text=provider["name"],
                             compound=tk.TOP, bg="#6E2594", fg="white", bd=0)
    provider_btn.image = provider_logo  # Retain a reference to the image to prevent garbage collection
    provider_btn.grid(row=idx // 4, column=idx % 2, padx=10, pady=5)

# Heading for frequently watched movies
movies_heading_label = tk.Label(root, text="Frequently Watched Movies", bg="#6E2594", fg="white", font=("Arial", 12))
movies_heading_label.place(x=500, y=50)

# Frequently watched movies on the left side in a 2 rows x 4 columns grid
movies_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
movies_frame.place(x=500, y=80, relwidth=0.375, relheight=0.75)

movies_list = [
    {"name": "Inception", "poster": "Inception.jpg"},
    {"name": "The Dark Knight", "poster": "DarkKnight.jpg"},
    {"name": "The Shawshank Redemption", "poster": "ShawShank.jpg"},
    {"name": "Pulp Fiction", "poster": "Pulpfiction.jpg"},
    {"name": "The Godfather", "poster": "Thegodfather.jpg"},
    {"name": "Fight Club", "poster": "Fightclub.jpg"},
    {"name": "Forrest Gump", "poster": "Forestgump.jpg"},
    {"name": "Interstellar", "poster": "interstellar.jpg"}
]

for idx, movie in enumerate(movies_list):
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\{movie['poster']}"
    img = Image.open(img_path)
    img = img.resize((100, 150))  # Resize posters
    movie_poster = ImageTk.PhotoImage(img)

    poster_label = tk.Label(movies_frame, image=movie_poster, text=movie["name"],
                            compound=tk.TOP, bg="#6E2594", fg="white", bd=0)
    poster_label.image = movie_poster  # Retain a reference to the image to prevent garbage collection
    poster_label.grid(row=idx // 4, column=idx % 2, padx=10, pady=5)

# Options on the right side
options_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
options_frame.place(x=950, y=50, relwidth=0.25, relheight=0.9)

options = [
    "Login", "Subscription & Payment", "Browse/Search Content", "View Playlist",
    "View/Play Media", "Create New Playlist", "Change & Manage Subscriptions", "Logout"
]

for idx, option in enumerate(options):
    option_btn = tk.Button(options_frame, text=option, bg="#6E2594", fg="white", bd=0, width=20)
    option_btn.grid(row=idx, column=0, padx=10, pady=5)

# Settings button at top right
settings_btn = tk.Button(root, text="Settings", command=display_settings, bg="#6E2594", fg="white")
settings_btn.place(x=1150, y=50)

root.mainloop()

# %%
import tkinter as tk
from PIL import Image, ImageTk

def display_settings():
    # Add code to display settings
    print("Displaying settings...")

# Create main window
root = tk.Tk()
root.title("Roku Main Menu")

# Load and display the background image
bg_image_path = "C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\Roku_lo.webp"
bg_image = Image.open(bg_image_path)
bg_photo = ImageTk.PhotoImage(bg_image.resize((1280, 720)))  # Resize background image
bg_label = tk.Label(root, image=bg_photo)
bg_label.place(x=0, y=0, relwidth=1, relheight=1)

# Content provider logos on the left side with a heading
content_providers = [
    {"name": "Netflix Standard ", "logo": "Netflix.png"},
    {"name": "Hulu", "logo": "Hulu.png"},
    {"name": "Amazon Prime Video", "logo": "Prime.png"},
    {"name": "Disney+ ", "logo": "DisneyP.png"},
    {"name": "HBO Max ", "logo": "HBO.jpg"},
    {"name": "Apple TV+ ", "logo": "Atv.jpg"},
    {"name": "Showtime ", "logo": "Showtime.png"},
    {"name": "CBS All Access ", "logo": "CBS.png"}
]

provider_heading_label = tk.Label(root, text="Content Providers", bg="#6E2594", fg="white", font=("Arial", 12))
provider_heading_label.place(x=50, y=50)

provider_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
provider_frame.place(x=50, y=80)

for idx, provider in enumerate(content_providers):
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\CP\\{provider['logo']}"
    img = Image.open(img_path)
    img = img.resize((100, 80))  # Resize images
    provider_logo = ImageTk.PhotoImage(img)

    provider_btn = tk.Button(provider_frame, image=provider_logo, text=provider["name"],
                             compound=tk.TOP, bg="#6E2594", fg="white", bd=0)
    provider_btn.image = provider_logo  # Retain a reference to the image to prevent garbage collection
    provider_btn.grid(row=idx // 4, column=idx % 4, padx=10, pady=5)

# Heading for frequently watched movies
movies_heading_label = tk.Label(root, text="Frequently Watched Movies", bg="#6E2594", fg="white", font=("Arial", 12))
movies_heading_label.place(x=50, y=310)

# Frequently watched movies on the left side in a 2 rows x 4 columns grid
movies_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
movies_frame.place(x=50, y=340)

movies_list = [
    {"name": "Inception", "poster": "Inception.jpg"},
    {"name": "The Dark Knight", "poster": "DarkKnight.jpg"},
    {"name": "The Shawshank Redemption", "poster": "ShawShank.jpg"},
    {"name": "Pulp Fiction", "poster": "Pulpfiction.jpg"},
    {"name": "The Godfather", "poster": "Thegodfather.jpg"},
    {"name": "Fight Club", "poster": "Fightclub.jpg"},
    {"name": "Forrest Gump", "poster": "Forestgump.jpg"},
    {"name": "Interstellar", "poster": "interstellar.jpg"}
]

for idx, movie in enumerate(movies_list):
    img_path = f"C:\\Users\\Sreecharan Vanam\\Desktop\\Fall-23\\SE\\Project\\Logos\\Movies\\{movie['poster']}"
    img = Image.open(img_path)
    img = img.resize((100, 150))  # Resize posters
    movie_poster = ImageTk.PhotoImage(img)

    poster_label = tk.Label(movies_frame, image=movie_poster, text=movie["name"],
                            compound=tk.TOP, bg="#6E2594", fg="white", bd=0)
    poster_label.image = movie_poster  # Retain a reference to the image to prevent garbage collection
    poster_label.grid(row=idx // 4, column=idx % 4, padx=10, pady=5)

# Options on the right side
options_frame = tk.Frame(root, bg="#6E2594")  # Use Roku-like purple color
options_frame.place(x=620, y=315)

options = [
    "Login", "Subscription & Payment", "Browse/Search Content", "View Playlist",
    "View/Play Media", "Create New Playlist", "Change & Manage Subscriptions", "Logout"
]

for idx, option in enumerate(options):
    option_btn = tk.Button(options_frame, text=option, bg="#6E2594", fg="white", bd=0, width=30)
    option_btn.grid(row=idx, column=0, padx=10, pady=5)

# Settings button at top right
settings_btn = tk.Button(root, text="Settings", command=display_settings, bg="#6E2594", fg="white")
settings_btn.place(x=620, y=315)

root.mainloop()
